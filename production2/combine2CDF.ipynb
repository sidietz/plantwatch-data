# %%
import pandas as pd
#from pandas.io.parsers import ParserError
import numpy as np
from helper import get_mapper
import json
import os
import re
import datetime

# %%
from os import listdir, stat
from os.path import isfile, join
BASE_DIR = "."
MIN_SIZE = 512

# %%
hours = (365 * 5 + 1) * 24
base = datetime.datetime(2015, 1, 1)
date_list = [base + datetime.timedelta(hours=x) for x in range(0, hours)]
COMPLETE = pd.DataFrame(data={'produced_at': date_list})
COMPLETE.produced_at = pd.to_datetime(COMPLETE.produced_at)

# %%
base_df = pd.DataFrame({'produced_at': pd.date_range(start='2015-01-01', end='2021-01-01', freq='1H')})

# %%
base_df.dtypes
# Out:
# produced_at    datetime64[ns]
# dtype: object

# %%
files = [f for f in os.listdir("combined")]

# %%
COMPLETE.dtypes
# Out:
# produced_at    datetime64[ns]
# dtype: object

# %%
def gen_power3(files):
    result = COMPLETE
    for f in files:
        final = pd.DataFrame()
        df = pd.read_csv("./combined/" + f, parse_dates=["produced_at"])
        #print(df.dtypes)
        try:
            df2 = df.merge(COMPLETE, on='produced_at', how='right')
        except ValueError:
            print(f)
        if final.empty:
            final = df2
        else:
            final = final.append(df2, sort=False)
        result = pd.merge(result, final, how='left', on=['produced_at'])
    return result.sort_values(by=['produced_at'])

# %%
cdf = gen_power3(files)
# Out:
# 07-05-8290552.csv

# %%
cdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_44368/2739600132.py in <module>
# ----> 1 cdf
#
# NameError: name 'cdf' is not defined

# %%
def combine2cdf():
    base_df = pd.DataFrame({'produced_at': pd.date_range(start='2015-01-01', end='2021-01-01', freq='1H')})
    #base_df['produced_at'] = base_df['produced_at'].astype(str)
    pdlist = [base_df]
    for f in os.listdir("combined"):
        #final = pd.DataFrame()
        tmp = pd.read_csv("combined/" + f)
        final = tmp.drop(columns=['produced_at'], axis=1)
        print(tmp.shape)
        #if final.empty:
        #    final = result
        #else:
        #    print("DEBUG!")
        #df['produced_at'] = df['produced_at'].astype(str)
        #df = pd.merge(base_df, df, on="produced_at", how='outer')
        pdlist.append(final)
        #result = pd.merge(result, result, how='left', on=['produced_at'])
        
    
    result = pd.concat(pdlist, axis=1)
        
        #df.merge(DATEDF_LIST[idx], on='produced_at', how='right')
    return result

# %%
#cdf = combine2cdf()

# %%
cdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_40946/2739600132.py in <module>
# ----> 1 cdf
#
# NameError: name 'cdf' is not defined

# %%
#cdf['produced_at'] = cdf['produced_at'].astype(pd.datetime64)
cdf['produced_at'] = pd.to_datetime(cdf['produced_at'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_40946/1258455716.py in <module>
#       1 #cdf['produced_at'] = cdf['produced_at'].astype(pd.datetime64)
# ----> 2 cdf['produced_at'] = pd.to_datetime(cdf['produced_at'])
#
# NameError: name 'pd' is not defined

# %%
gm = cdf.resample('1M', on='produced_at').sum()

# %%
gm
# Out:
#              produced_at                                            BNA0879  \
# produced_at
# 2015-01-31           NaN  ----------------------------------------------...
# 2015-02-28           NaN  0000000000000000000000001922643003263092592722...
# 2015-03-31           NaN  2102112112112112102112101971811791851871851841...
# 2015-04-30           NaN  2302302302292382312172132092072041991991971971...
# 2015-05-31           NaN  2385000000000000000000000000000000000000000291...
# ...                  ...                                                ...
# 2020-09-30           NaN  0000000000000000000000000000000000000000000000...
# 2020-10-31           NaN  1371371361371371381421421411411421421421411431...
# 2020-11-30           NaN  1741731661621682292542013143303243263253253293...
# 2020-12-31           NaN                                                NaN
# 2021-01-31           NaN                                                  0
#
#                                                        BNA0878  \
# produced_at
# 2015-01-31   ----------------------------------------------...
# 2015-02-28
# 2021-01-31                                                   0
#
#                                                        BNA0087  \
# produced_at
# 2015-01-31   ----------------------------------------------...
# 2015-02-28   0000000000000000000000000000000000000000000000...
# 2015-03-31   0000000000000000000000000000000000000000000000...
# 2015-04-30   1631631641631651691671621621621641641621581581...
# 2015-05-31   1721691681691671671701681721751701671661671691...
# ...                                                        ...
# 2020-09-30   0000000000000000000000000000000000000000000000...
# 2020-10-31   0000000000000000000000000000000000000000000000...
# 2020-11-30   1311261261271271321471962042042042042042042042...
# 2020-12-31                                                 NaN
# 2021-01-31                                                   0
#
#                                                        BNA0793  \
# produced_at
# 2015-01-31   0000000000000000000000000000000000000000000000...
# 2015-02-28   0000000000000000000000000000000000000000000000...
# 2015-03-31   0000321402353174465397058178717997427897237528...
# 2015-04-30   0000002112922023928033827721319218719019020231...
# 2015-05-31   2318000000000000000000000000001257402705601289...
# ...                                                        ...
# 2020-09-30   0000000000000000000000000000000000000000000000...
# 2020-10-31   0000000000000000000000000000000000000000000000...
# 2020-11-30                                                 NaN
# 2020-12-31                                                   0
# 2021-01-31                                                   0
#
#                                                        BNA0526
# produced_at
# 2015-01-31   1441431451441441451441521511511521521511511812...
# 2015-02-28   2762782822612462732852862862852852842832862862...
# 2015-03-31   1611361401401541912692672702772842692122122142...
# 2015-04-30   2582142242212562172142181631561531901651671651...
# 2015-05-31   1321311311291291952591301201211271281281281281...
# ...                                                        ...
# 2020-09-30                                                   0
# 2020-10-31                                                   0
# 2020-11-30                                                   0
# 2020-12-31                                                   0
# 2021-01-31                                                   0
#
# [73 rows x 216 columns]

# %%
gm2 = gm.reset_index()
#gm2['year'] = gm2['produced_at2']
#gm2['month'] = gm2['produced_at3']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-4814043c4b7d> in <module>
# ----> 1 gm2 = gm.reset_index()
#       2 #gm2['year'] = gm2['produced_at2']
#       3 #gm2['month'] = gm2['produced_at3']
#
# /opt/conda/envs/conda/lib/python3.9/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5014                 # to ndarray and maybe infer different dtype
#    5015                 level_values = maybe_casted_values(lev, lab)
# -> 5016                 new_obj.insert(0, name, level_values)
#    5017
#    5018         new_obj.index = new_index
#
# /opt/conda/envs/conda/lib/python3.9/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# -> 3763         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3764
#    3765     def assign(self, **kwargs) -> DataFrame:
#
# /opt/conda/envs/conda/lib/python3.9/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1189         if not allow_duplicates and item in self.items:
#    1190             # Should this be a different kind of error??
# -> 1191             raise ValueError(f"cannot insert {item}, already exists")
#    1192
#    1193         if not isinstance(loc, int):
#
# ValueError: cannot insert produced_at, already exists

# %%
def gen_power3(files):
    result = COMPLETE
    for plant, files in FILES_DICT.items():
        final = pd.DataFrame()
        for idx, f in enumerate(files):
            f = "fix/" + f
            df = pd.read_csv(f, parse_dates=["produced_at"])
            df2 = df.merge(DATEDF_LIST[idx], on='produced_at', how='right')
            if final.empty:
                final = df2
            else:
                final = final.append(df2, sort=False)
        result = pd.merge(result, final, how='left', on=['produced_at'])
    return result.sort_values(by=['produced_at'])
