# %%
import pandas as pd
import numpy as np
import re
import json
from helpers import match_inspire

# %%
bm = pd.read_csv("../basic/inspire_prtr_mapper.csv", engine="python")

# %%
mibue = "https://registry.gdi-de.org/id/de.hb/de.hb.pf.bube-eureg.06-04-11/2000122/0/0"

# %%
mb_id = match_inspire(mibue)

# %%
mb_id
# Out:
# 'HB06-04-11/2000122/0/0'
