# %%
import pandas as pd

# %%
ml = pd.read_csv("monthly.csv", names=['mid', 'year', 'month', 'seeid', 'power'])

# %%
#o1 = "BNA0413c"
#o2 = "BNA051a"
#o3 = "BNA0696"
#o4 = "BNA0697"
o5 = "BNA0705"
o6 = "BNA0712"
#o7 = "BNA1025"

# %%
walsum = "BNA0216a"

# %%
ml2 = ml.loc[ml.seeid != walsum].loc[ml.seeid != o1].loc[ml.seeid != o2].loc[ml.seeid != o3].loc[ml.seeid != o4].loc[ml.seeid != o5].loc[ml.seeid != o6]

# %%
ml3 = ml2.loc[ml.seeid != o7].loc[ml.seeid != o2].loc[ml.seeid != o3].loc[ml.seeid != o4].loc[ml.seeid != o5].loc[ml.seeid != o6]

# %%
ml3.to_csv("ml2.csv", header=False, index=False)
