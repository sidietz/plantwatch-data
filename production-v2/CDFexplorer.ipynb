# %%
import pandas as pd

# %%
cdf =  pd.read_csv("CDF.csv")

# %%
cdf.dtypes
# Out:
# produced_at     object
# variable        object
# value          float64
# dtype: object

# %%
cdf.loc[cdf.variable == 'SN80011277']
# Out:
# Empty DataFrame
# Columns: [produced_at, variable, value]
# Index: []
