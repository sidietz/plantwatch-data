# %%
import pandas as pd
from helpers import get_factor, get_price
pd.options.mode.chained_assignment = None

# %%
CDF = pd.read_csv("../production-v2/CDF.csv")
raw_sse = pd.read_csv("../basic/inspire_prtr_mapper.csv")
see = raw_sse.rename(columns={"InspireID_Betrieb": "plantid"})
seem = see[['plantid', 'sseid']]
#bpm['plantid'] = bpm['plantid'].apply(lambda x: str(x).replace('/', '_'))
seem['plantid'] = seem['plantid'].apply(lambda x: str(x).replace('/', '_'))

# %%
#CDF.sort_values(by=["produced_at", "variable"])

# %%
smard = pd.read_csv("Gro_handelspreise_202501010000_202601010000_Viertelstunde.csv", sep=";", na_values="-", decimal=",", thousands=".")
smardlog = smard[["Datum von", "Deutschland/Luxemburg [€/MWh] Originalauflösungen"]]
smardlog.rename(columns={"Datum von": "timestamp", "Deutschland/Luxemburg [€/MWh] Originalauflösungen": "price"}, inplace=True)
smardlog["timestamp"] = pd.to_datetime(smardlog["timestamp"], format="mixed")

# %%
smardlog['timestamp'] = smardlog['timestamp'] + pd.offsets.DateOffset(years=-1)

# %%
smardlog.dtypes
# Out:
# timestamp    datetime64[ns]
# price               float64
# dtype: object

# %%
smardlog_2024 = pd.read_excel("GHP_2023.xlsx")[['timestamp', 'price']]

# %%
smardlog.to_excel("GHP_2025.xlsx", index=False)

# %%
smardlog.describe()
# Out:
#                            timestamp         price
# count                          35040  35040.000000
# mean   2024-07-02 08:34:15.205479424     89.321723
# min              2024-01-01 00:00:00   -250.320000
# 25%              2024-04-02 06:56:15     70.570000
# 50%              2024-07-02 12:52:30     92.325000
# 75%              2024-10-01 18:48:45    114.160000
# max              2024-12-31 23:45:00    583.400000
# std                              NaN     52.475480

# %%
smardlog_2024.describe()
# Out:
#                            timestamp         price
# count                          35136  35136.000000
# mean   2024-07-02 00:26:55.573770496     78.512033
# min              2024-01-01 00:00:00   -135.450000
# 25%              2024-04-01 12:56:15     55.560000
# 50%              2024-07-02 00:52:30     79.585000
# 75%              2024-10-01 12:48:45    101.340000
# max              2024-12-31 23:45:00    936.280000
# std                              NaN     52.724158

# %%
smardlog.sort_values('price')
# Out:
#                 timestamp   price
# 12529 2024-11-05 13:15:00 -250.32
# 12530 2024-11-05 13:30:00 -250.32
# 12528 2024-11-05 13:00:00 -250.32
# 12531 2024-11-05 13:45:00 -250.32
# 12535 2024-11-05 14:45:00 -230.98
# ...                   ...     ...
# 27527 2024-10-14 18:45:00  508.38
# 1893  2024-01-20 17:15:00  583.40
# 1894  2024-01-20 17:30:00  583.40
# 1895  2024-01-20 17:45:00  583.40
# 1892  2024-01-20 17:00:00  583.40
#
# [35040 rows x 2 columns]

# %%
co2s = pd.read_csv("../pollution/pollutants.csv")
nat_mp = pd.read_csv("nat_mapper_2025.csv")
plantlist = pd.read_csv("../basic/plants_2.csv")
nat_mp.fillna(0, inplace=True)

# %%
#co2s['year'] = co2s['year'] + 1

# %%
#co2s

# %%
CDF2 = CDF.loc[CDF.produced_at > "2023-12-31 23:50"].loc[CDF.produced_at < "2025-01-01 00:00"]

# %%
CDF2['produced_at'] = pd.to_datetime(CDF2['produced_at'])

# %%
CDF2
# Out:
#                  produced_at         variable  value
# 78879    2024-01-01 00:00:00  SEE913896693631    0.0
# 78880    2024-01-01 01:00:00  SEE913896693631    0.0
# 78881    2024-01-01 02:00:00  SEE913896693631    0.0
# 78882    2024-01-01 03:00:00  SEE913896693631    0.0
# 78883    2024-01-01 04:00:00  SEE913896693631    0.0
# ...                      ...              ...    ...
# 43493831 2024-12-31 22:45:00  SEE960652233358    0.0
# 43493832 2024-12-31 23:00:00  SEE960652233358    0.0
# 43493833 2024-12-31 23:15:00  SEE960652233358    0.0
# 43493834 2024-12-31 23:30:00  SEE960652233358    0.0
# 43493835 2024-12-31 23:45:00  SEE960652233358    0.0
#
# [3899652 rows x 3 columns]

# %%
CDF2a = CDF2.copy()#loc[~(CDF2.variable.str.contains("Unnamed"))]

# %%
#CDF2b = CDF2a.groupby('variable').resample('1h', on='produced_at').mean()

# %%
CDF3 = CDF2a

# %%
#CDF3 = CDF2.dropna()

# %%
len(CDF2) - len(CDF3)
# Out:
# 0

# %%
len(CDF2.groupby('produced_at').sum())
# Out:
# 35132

# %%
dataset = CDF3.merge(seem, left_on="variable", right_on="sseid", how="inner")

# %%
dataset2 = dataset.drop_duplicates(subset=['produced_at', 'variable'])

# %%
len(dataset)
# Out:
# 3750341

# %%
dataset
# Out:
#                 produced_at         variable  value           plantid  \
# 0       2024-01-01 00:00:00  SEE913896693631    0.0  06-02-B10117A007
# 1       2024-01-01 01:00:00  SEE913896693631    0.0  06-02-B10117A007
# 2       2024-01-01 02:00:00  SEE913896693631    0.0  06-02-B10117A007
# 3       2024-01-01 03:00:00  SEE913896693631    0.0  06-02-B10117A007
# 4       2024-01-01 04:00:00  SEE913896693631    0.0  06-02-B10117A007
# ...                     ...              ...    ...               ...
# 3750336 2024-12-31 22:45:00  SEE960652233358    0.0          ST100125
# 3750337 2024-12-31 23:00:00  SEE960652233358    0.0          ST100125
# 3750338 2024-12-31 23:15:00  SEE960652233358    0.0          ST100125
# 3750339 2024-12-31 23:30:00  SEE960652233358    0.0          ST100125
# 3750340 2024-12-31 23:45:00  SEE960652233358    0.0          ST100125
#
#                    sseid
# 0        SEE913896693631
# 1        SEE913896693631
# 2        SEE913896693631
# 3        SEE913896693631
# 4        SEE913896693631
# ...                  ...
# 3750336  SEE960652233358
# 3750337  SEE960652233358
# 3750338  SEE960652233358
# 3750339  SEE960652233358
# 3750340  SEE960652233358
#
# [3750341 rows x 5 columns]

# %%
magic = dataset2.groupby(["produced_at", "plantid"]).sum()

# %%
#magic

# %%
magic2 = magic[["value"]]

# %%
#magic2.sort_values(["produced_at", "value"])

# %%
production = magic2.reset_index()
production["produced_at"] = pd.to_datetime(production["produced_at"], format="mixed")

# %%
merged = production.merge(smardlog, left_on="produced_at", right_on="timestamp")
merged["revenue"] = merged["value"] * merged["price"]

# %%
merged_mytmp = merged[['produced_at', 'plantid', 'value', 'price', 'revenue']]

# %%
merged_mytmp.loc[merged_mytmp.plantid == "BB45025564"].sort_values('revenue').resample('1YE', on='produced_at').sum()
# Out:
#                                                        plantid      value  \
# produced_at
# 2024-12-31   BB45025564BB45025564BB45025564BB45025564BB4502...  9513820.0
#
#                   price       revenue
# produced_at
# 2024-12-31   3129575.52  9.021745e+08

# %%
#merged1a = merged.groupby('plantid').resample('1h', on='produced_at').mean().reset_index()

# %%
#merged1a.sort_values('revenue')

# %%
#merged

# %%
#production.sort_values(by=["plantid", "produced_at"])

# %%
#merged1a

# %%
#merged_tmp = merged.drop(columns=["timestamp"])
#merged1a = merged_tmp.set_index("produced_at", drop=True)

# %%
#merged1a = merged_tmp.set_index(['plantid']).sort_values(['plantid', 'produced_at'])

# %%
#merged2 = merged1a.resample("1h", on="produced_at").agg({'value':'sum', 'price':'sum', 'revenue': 'sum' })

# %%
#merged1a

# %%
#tmp1 = merged2.copy()
tmp1 = merged[["plantid", "value", "price", "revenue"]].groupby("plantid").sum()

# %%
tmp1.reset_index(inplace=True)

# %%
revenue = tmp1[["plantid", "revenue"]]

# %%
#tmp1

# %%
#dataset.sort_values(["plantid", "produced_at"])

# %%
plantlist2 = plantlist[["plantid", "energysource"]]
plantlist3 = plantlist2.merge(nat_mp, on="plantid")

# %%
tmp0 = pd.merge(revenue, plantlist3, on="plantid")
tmp0["factor"] = tmp0["energysource"].apply(get_factor)
tmp0["fuel_price"] = tmp0["energysource"].apply(get_price)

# %%
#prod2 = prod.loc[prod.year == 2023].loc[prod.yearpower > 1000000]
co2s2 = co2s.loc[co2s.year == 2024].loc[co2s.pollutant == "CO2"]

# %%
co2s2.drop_duplicates(subset=["year", "plantid", "pollutant"], inplace=True)

# %%
#co2s2

# %%
co2s3 = co2s2[["plantid", "amount_2"]]

# %%
tmp1 = pd.merge(tmp0, co2s3, on="plantid")

# %%
tmp2 = pd.merge(tmp1, production, on="plantid")

# %%
tmp2 = tmp1

# %%
coal_cost_per_t = 103.5# or 120
co2_cost = 74 # https://www.umweltbundesamt.de/presse/pressemitteilungen/emissionshandel-21-milliarden-euro-fliessen-in-den
# https://icapcarbonaction.com/system/files/ets_pdfs/icap-etsmap-factsheet-43.pdf
#electricity_price = 78.50

# %%
#tmp2

# %%
tmp2["co2_cost"] = (tmp2["amount_2"] * 10**6 - tmp2["free_co2s"]) * co2_cost / 10**6
tmp2["coal_cost"] = (tmp2["amount_2"] * 10**6 * 1/tmp2["factor"] * tmp2["fuel_price"]) / 10**6

# %%
tmp2["profit"] = (tmp2["revenue"] / 10**6) - (tmp2["co2_cost"] + tmp2["coal_cost"])

# %%
#tmp2

# %%
#tmp2.sort_values(by="free_co2s", ascending=False)

# %%
profit = tmp2[["plantid", "plantname", "revenue", "profit"]]
profit["revenue"] = profit["revenue"].apply(lambda x: x / 10**6)

# %%
profit.sort_values("profit", ascending=False)
# Out:
#                       plantid                              plantname  \
# 15                   BYS00048                          Irsching 5 DT
# 22              NI10257673950                           Emsland B DT
# 23              NW100-0167182                           SWD KWF GTKW
# 25              NW100-0248923                              Neurath F
# 46                 SN80011277           Kraftwerk Lippendorf Block S
# 28              NW300-0370387                DT Niehl 2 RheinEnergie
# 39              NW900-9140178     Trianel Gaskraftwerk Hamm Block 10
# 31              NW300-9002708                            Dormagen DT
# 5                    BE172654                 HKW Mitte Dampfturbine
# 32              NW300-9046030      Knapsack I - Dampfturbine - DT 10
# 14                   BYS00044                  SWM HKW Sued GuD1 GT2
# 36              NW900-0125939      Cuno Heizkraftwerk Herdecke BHKW1
# 45                 SN70015796                        Boxberg Block N
# 27              NW300-0326774                          Niederaußem G
# 6                    BE172656               GuD Marzahn Dampfturbine
# 2                  BB45025611       Kraftwerk Schwarze Pumpe Block A
# 24              NW100-0229264                       HKW III  Block A
# 19              NI01010098080                            KWM Block 3
# 44                SL0105352-G                Dampfturbinenanlage DT3
# 4                    BE169709         HKW Klingenberg Dampfturbine 1
# 37              NW900-0205103                            Bergkamen A
# 18                 MV30000226              Kraftwerk Rostock Block A
# 34              NW500-0915123                              Datteln 4
# 12                   BYS00009                      Kraftwerk Zolling
# 43                SL0101003-G                               Weiher 3
# 40              NW900-9141660           Trianel Kohlekraftwerk Lünen
# 38              NW900-0327252                              GuD Herne
# 42                SL0100999-G                                Bexbach
# 35              NW700-0105516                               Heyden 4
# 30              NW300-0923949         Block 4 Merkenich RheinEnergie
# 8   BWpf-450-1195689-00000000  Heizkraftwerk Stuttgart-Münster DT 12
# 47                   ST100125                             Schkopau A
# 17                 HE30001045                           Staudinger 4
# 7   BWpf-450-1020129-00000000          Heizkraftwerk Heilbronn FHT 1
# 9   BWpf-450-1741292-00000000  Heizkraftwerk  Altbach/Deizisau HKW 1
# 21              NI06060316030                                  GKH 1
# 10  BWpf-450-2797933-00000000  Rheinhafen- Dampfkraftwerk  RDK 4S DT
# 16                   BYS00114                   Gasturbinenanlage 12
# 29              NW300-0877384                           Weisweiler F
# 3                    BE166928         HKW Reuter West Dampfturbine D
# 1                  BB45025564          Kraftwerk Jänschwalde Block A
# 33              NW500-0342658                          Scholven 1 DT
# 13                   BYS00041                     SWM HKW Nord 2 T20
# 20              NI01241117210                 DT30 GuD Süd Wolfsburg
# 26              NW100-0365906                              Walsum 10
# 11  BWpf-450-2948214-00000000                            GKM Block 6
# 0                  BB23020490                                   1MKA
# 41                  RP5000671                         GuD Mitte DT10
#
#         revenue      profit
# 15   357.246201  227.386201
# 22   301.656254  186.096580
# 23   263.085984  164.130651
# 25  1187.301991  123.378988
# 46   565.427126  112.808021
# 28   219.186454  103.218454
# 39   132.185978   84.570645
# 31   135.061712   67.313045
# 5    127.173536   65.377086
# 32   112.465133   64.145133
# 14   106.869396   55.630063
# 36    80.676611   48.060611
# 45  1146.480136   46.436272
# 27   981.344994   43.047874
# 6     92.553058   41.693738
# 2    655.785999   28.393789
# 24    34.128614   14.901281
# 19    54.529096    5.118231
# 44    14.071483    3.702816
# 4     35.805329   -0.937929
# 37    27.209600   -1.261593
# 18    60.178252   -3.246548
# 34   198.825520   -4.234950
# 12   100.357407   -5.590891
# 43    16.047329   -7.114014
# 40   246.058102   -9.900224
# 38    16.097425   -9.914546
# 42    24.768377  -10.389354
# 35    23.699739  -17.040470
# 30     0.000000  -23.782000
# 8     19.474931  -31.004919
# 47   310.619842  -31.062427
# 17    32.219021  -33.345397
# 7     54.604057  -37.209883
# 9     48.974416  -40.745282
# 21    88.594929  -41.583698
# 10   191.278702  -43.066582
# 16    13.139349  -45.045985
# 29   782.163416  -49.938390
# 3    113.278756  -53.738620
# 1    902.174453  -71.843430
# 33    32.964248  -71.914435
# 13    75.012671  -71.960662
# 20    43.984333  -72.653816
# 26    36.958857 -119.688406
# 11   189.545224 -177.195674
# 0    122.240428 -227.116268
# 41   173.697326 -341.716007

# %%
profit.sort_values("profit", ascending=False)
# Out:
#                       plantid                              plantname  \
# 14                   BYS00048                          Irsching 5 DT
# 21              NI10257673950                           Emsland B DT
# 22              NW100-0167182                           SWD KWF GTKW
# 24              NW100-0248923                              Neurath F
# 45                 SN80011277           Kraftwerk Lippendorf Block S
# 27              NW300-0370387                DT Niehl 2 RheinEnergie
# 38              NW900-9140178     Trianel Gaskraftwerk Hamm Block 10
# 30              NW300-9002708                            Dormagen DT
# 4                    BE172654                 HKW Mitte Dampfturbine
# 31              NW300-9046030      Knapsack I - Dampfturbine - DT 10
# 13                   BYS00044                  SWM HKW Sued GuD1 GT2
# 35              NW900-0125939      Cuno Heizkraftwerk Herdecke BHKW1
# 5                    BE172656               GuD Marzahn Dampfturbine
# 44                 SN70015796                        Boxberg Block N
# 26              NW300-0326774                          Niederaußem G
# 23              NW100-0229264                       HKW III  Block A
# 18              NI01010098080                            KWM Block 3
# 43                SL0105352-G                Dampfturbinenanlage DT3
# 3                    BE169709         HKW Klingenberg Dampfturbine 1
# 36              NW900-0205103                            Bergkamen A
# 17                 MV30000226              Kraftwerk Rostock Block A
# 33              NW500-0915123                              Datteln 4
# 11                   BYS00009                      Kraftwerk Zolling
# 42                SL0101003-G                               Weiher 3
# 37              NW900-0327252                              GuD Herne
# 41                SL0100999-G                                Bexbach
# 39              NW900-9141660           Trianel Kohlekraftwerk Lünen
# 34              NW700-0105516                               Heyden 4
# 29              NW300-0923949         Block 4 Merkenich RheinEnergie
# 7   BWpf-450-1195689-00000000  Heizkraftwerk Stuttgart-Münster DT 12
# 16                 HE30001045                           Staudinger 4
# 46                   ST100125                             Schkopau A
# 6   BWpf-450-1020129-00000000          Heizkraftwerk Heilbronn FHT 1
# 8   BWpf-450-1741292-00000000  Heizkraftwerk  Altbach/Deizisau HKW 1
# 20              NI06060316030                                  GKH 1
# 9   BWpf-450-2797933-00000000  Rheinhafen- Dampfkraftwerk  RDK 4S DT
# 15                   BYS00114                   Gasturbinenanlage 12
# 2                    BE166928         HKW Reuter West Dampfturbine D
# 28              NW300-0877384                           Weisweiler F
# 32              NW500-0342658                          Scholven 1 DT
# 12                   BYS00041                     SWM HKW Nord 2 T20
# 19              NI01241117210                 DT30 GuD Süd Wolfsburg
# 1                  BB45025564          Kraftwerk Jänschwalde Block A
# 25              NW100-0365906                              Walsum 10
# 10  BWpf-450-2948214-00000000                            GKM Block 6
# 0                  BB23020490                                   1MKA
# 40                  RP5000671                         GuD Mitte DT10
#
#         revenue      profit
# 14   357.246201  226.096201
# 21   301.656254  184.960188
# 22   263.085984  163.147651
# 24  1187.301991  110.002989
# 45   565.427126  107.120478
# 27   219.186454  102.066454
# 38   132.185978   84.097645
# 30   135.061712   66.640045
# 4    127.173536   64.784161
# 31   112.465133   63.665133
# 13   106.869396   55.121063
# 35    80.676611   47.736611
# 5     92.553058   41.194558
# 44  1146.480136   32.606357
# 26   981.344994   31.252915
# 23    34.128614   14.710281
# 18    54.529096    4.702231
# 43    14.071483    3.599816
# 3     35.805329   -1.280946
# 36    27.209600   -1.501119
# 17    60.178252   -3.775080
# 33   198.825520   -5.944319
# 11   100.357407   -6.482891
# 42    16.047329   -7.309014
# 37    16.097425  -10.133546
# 41    24.768377  -10.685354
# 39   246.058102  -12.054562
# 34    23.699739  -17.383470
# 29     0.000000  -24.081000
# 7     19.474931  -31.429919
# 16    32.219021  -33.897397
# 46   310.619842  -35.357177
# 6     54.604057  -37.982883
# 8     48.974416  -41.494217
# 20    88.594929  -42.679698
# 9    191.278702  -45.039582
# 15    13.139349  -45.623985
# 2    113.278756  -55.120662
# 28   782.163416  -60.399167
# 32    32.964248  -72.779274
# 12    75.012671  -73.420662
# 19    43.984333  -73.635816
# 1    902.174453  -84.088470
# 25    36.958857 -121.001106
# 10   189.545224 -180.248647
# 0    122.240428 -230.393268
# 40   173.697326 -346.836007

# %%
profit_combined = pd.concat([profit, profit2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 profit_combined = pd.concat([profit, profit2])
#
# NameError: name 'profit2' is not defined

# %%
profit_final = profit_combined.drop_duplicates(subset="plantid", keep="first").sort_values('profit')

# %%
#profit.to_csv("profit.csv", index=False)

# %%
pd.concat([profit2, profit, profit]).drop_duplicates(keep=False)

# %%
#profit_final.reset_index()

# %%
pd.concat([profit, profit2, profit2]).drop_duplicates(keep=False).sort_values('profit', ascending=False)

# %%
#profit2 = profit

# %%
profit2.sort_values("profit", ascending=False)
