# %%
import pandas as pd
import psycopg
from sqlalchemy import create_engine, inspect, DateTime
from datetime import datetime

# %%
engine2 = create_engine('postgresql+psycopg://smardlog:N0m1596.@127.0.0.1/smardlog')
smardlog = pd.read_sql_table('smardlog', engine2)

# %%
smdl = smardlog.drop(columns="id")

# %%
dt = pd.read_csv("Datteln_202503010000_202504242359_Stunde.csv", sep=";", na_values="-", decimal=",", thousands=".")
dt.fillna(0.0, inplace=True)
dt["Datum von"] = pd.to_datetime(dt["Datum von"], format="mixed")

# %%
merged = smdl.merge(dt, left_on="timestamp", right_on="Datum von")

# %%
merged2 = merged[["timestamp", "Generation_DE Datteln 4 [MW] Originalauflösungen", "price"]]

# %%
merged2["revenue"] = merged2["Generation_DE Datteln 4 [MW] Originalauflösungen"] * merged2["price"]
# Out:
# /tmp/ipykernel_943228/4186250792.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged2["revenue"] = merged2["Generation_DE Datteln 4 [MW] Originalauflösungen"] * merged2["price"]

# %%
merged2
# Out:
#               timestamp  Generation_DE Datteln 4 [MW] Originalauflösungen  \
# 0   2025-03-14 14:00:00                                             922.0
# 1   2025-03-19 10:00:00                                             903.0
# 2   2025-03-19 15:00:00                                             442.0
# 3   2025-03-19 16:00:00                                             750.0
# 4   2025-03-19 21:00:00                                             920.0
# ..                  ...                                               ...
# 101 2025-04-24 17:00:00                                               0.0
# 102 2025-04-24 19:00:00                                               0.0
# 103 2025-04-24 20:00:00                                               0.0
# 104 2025-04-24 21:00:00                                               0.0
# 105 2025-04-24 22:00:00                                               0.0
#
#       price    revenue
# 0    104.59   96431.98
# 1     79.50   71788.50
# 2      0.99     437.58
# 3     66.73   50047.50
# 4    176.68  162545.60
# ..      ...        ...
# 101   83.37       0.00
# 102  101.02       0.00
# 103  114.64       0.00
# 104   40.50       0.00
# 105  114.48       0.00
#
# [106 rows x 4 columns]

# %%
income = merged2["revenue"].sum() / len(merged2) # per hour

# %%
income
# Out:
# np.float64(35496.225)
