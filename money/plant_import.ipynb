# %%
import pandas as pd

# %%
plts = pd.read_csv("../basic/blocks_2.csv")

# %%
plts2 = plts[["plantid", "plantname"]]

# %%
plts3 = plts2.dropna(subset=["plantid"])
plts3.drop_duplicates("plantid", inplace=True)
# Out:
# /tmp/ipykernel_2599428/2500607807.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plts3.drop_duplicates("plantid", inplace=True)

# %%
#plts3.to_csv("plants.csv", index=False)

# %%
plts3
# Out:
#                          plantid                              plantname
# 1     BWpf-450-80920445-00000000                              HKW Aalen
# 6                       SD661-59                              Turbine 4
# 8      BWpf-450-1741292-00000000  Heizkraftwerk  Altbach/Deizisau HKW 1
# 17                    MV60004935                             Kesselhaus
# 18                     RP5000221                         Dampfturbine 7
# ...                          ...                                    ...
# 1500                    BYS00894                              ST_HKW_T4
# 1515                    SD661-87                         BKR Gasturbine
# 1516               NI01010098080                            KWM Block 3
# 1536   BWpf-450-4124448-00000000                          HKW Oberkirch
# 1537               NW700-0105516                               Heyden 4
#
# [351 rows x 2 columns]
