# %%
import pandas as pd
import numpy as np

# %%
pl0 = pd.read_csv("Kraftwerksliste_CSV.csv", error_bad_lines=False, engine="python", encoding="latin1", sep=";", skiprows=9)
bm = pd.read_csv("block_plant_mapper.csv", error_bad_lines=False, engine="python")

# %%
pl0.rename(columns={ pl0.columns[10]: "Energieträger_old", pl0.columns[13]: "Energieträger"}, inplace=True)

# %%
#pl0

# %%
#bm
pl1 = pl0.loc[np.logical_or(pl0.Energieträger == "Kernenergie", np.logical_or(pl0.Energieträger == "Erdgas", np.logical_or(pl0.Energieträger == "Steinkohle", pl0.Energieträger == "Braunkohle"))), :]

# %%
pl2 = pl1.rename(columns={ pl1.columns[0]: "BlockID", pl1.columns[3]: "PLZ", pl1.columns[4]: "Ort", pl1.columns[8]: "Inbetriebnahme", pl1.columns[9]: "Status", pl1.columns[15]: "KWK", pl1.columns[16]: "Nettoleistung"})

# %%
cols = [10, 11,12,14,17,18,19]
pl3 = pl2.drop(pl2.columns[cols],axis=1)

# %%
pl3
# Out:
#        BlockID                                        Unternehmen  \
# 6      BNA0005                      Lausitz Energie Kraftwerke AG
# 7      BNA0006                      Lausitz Energie Kraftwerke AG
# 8      BNA0007                      Lausitz Energie Kraftwerke AG
# 9      BNA0008                      Lausitz Energie Kraftwerke AG
# 15    BNA0012b                                  Sappi Alfeld GmbH
# 22     BNA0015                  EnBW Energie Baden-Württemberg AG
# 23     BNA0016                  EnBW Energie Baden-Württemberg AG
# 24     BNA0017                  EnBW Energie Baden-Württemberg AG
# 25     BNA0018                  EnBW Energie Baden-Württemberg AG
# 26     BNA0019                  EnBW Energie Baden-Württemberg AG
# 27     BNA0020                  EnBW Energie Baden-Württemberg AG
# 36     BNA0025                          Suiker Unie GmbH & Co. KG
# 38     BNA1458                                      Buchmann GmbH
# 43     BNA1331                       Reno De Medici Arnsberg GmbH
# 50    BNA1337e                    DS Smith Paper Deutschland GmbH
# 54     BNA1103                             UPM GmbH Werk Augsburg
# 55     BNA0033                   Stadtwerke Augsburg Energie GmbH
# 56     BNA1104                   Stadtwerke Augsburg Energie GmbH
# 70     BNA1507  Michelin Reifenwerke AG & Co. KGaA \nStandort ...
# 77     BNA1105                               Thüringer Energie AG
# 83     BNA0051                           Cargill Deutschland GmbH
# 96    BNA0059b                                      Volkswagen AG
# 110    BNA0705                                       RWE Power AG
# 111    BNA0706                                       RWE Power AG
# 112    BNA0707                                       RWE Power AG
# 113    BNA0708                                       RWE Power AG
# 114    BNA0709                                       RWE Power AG
# 115    BNA0710                                       RWE Power AG
# 116    BNA0711                                       RWE Power AG
# 117    BNA0712                                       RWE Power AG
# ...        ...                                                ...
# 2018   BNA0099                            Uniper Kraftwerke GmbH
# 2019   BNA0355                                E.ON Kernkraft GmbH
# 2020   BNA0813                            Uniper Kraftwerke GmbH
# 2021   BNA0810                            Uniper Kraftwerke GmbH
# 2022   BNA0811                            Uniper Kraftwerke GmbH
# 2023   BNA0681                                  SWM Services GmbH
# 2024   BNA0682                                  SWM Services GmbH
# 2022                                        NaN     Nordrhein-Westfalen
# 2023                                        NaN                  Bayern
# 2024                                        NaN                  Bayern
# 2025                          Marguerrestraße 1       Baden-Württemberg
# 2026                          Marguerrestraße 1       Baden-Württemberg
# 2027                                        NaN     Nordrhein-Westfalen
# 2028                       Athenslebener Weg 57          Sachsen-Anhalt
# 2029                          Ostpreußendamm 61                  Berlin
# 2030                            Batteriestr. 48      Schleswig-Holstein
# 2031                            Batteriestr. 48      Schleswig-Holstein
# 2033                                        NaN     Nordrhein-Westfalen
# 2034                            Hohwiesenweg 15       Baden-Württemberg
# 2035                                        NaN             Brandenburg
# 2036                                        NaN             Brandenburg
# 2037                                        NaN             Brandenburg
# 2038                   Hastedter Osterdeich 255                  Bremen
# 2039                              Otavistr. 7-9                  Bremen
# 2040                                        NaN     Nordrhein-Westfalen
# 2041                        Paul-Baumann-Str. 1     Nordrhein-Westfalen
# 2042                           Lyoner Straße  9                  Hessen
# 2046                           Hertener Str. 16     Nordrhein-Westfalen
# 2047                        Frankfurter Str 430     Nordrhein-Westfalen
# 2048                        Frankfurter Str 430     Nordrhein-Westfalen
# 2049                       Frankfurter Str. 430     Nordrhein-Westfalen
# 2050                       Frankfurter Str. 430     Nordrhein-Westfalen
# 2051                                        NaN                  Bayern
#
#                        Blockname Inbetriebnahme  \
# 6                           GT A           1990
# 7                           GT B           1990
# 8                           GT C           1990
# 9                           GT D           1990
# 15                  Gaskraftwerk           1947
# 22               ALT GT E (solo)           1997
# 23               ALT GT A (Solo)           1971
# 24                      ALT GT B           1973
# 25                      ALT GT C           1975
# 26    ALT HKW 2 (DT Solobetrieb)           1997
# 27                     ALT HKW 1           1985
# 36                           NaN           1993
# 38                           NaN           1975
# 43                HD - Kraftwerk           1923
# 50                    GuD-Anlage           2013
# 54                Dampfturbine 3           1966
# 55                            GT           2004
# 56                            T2           1976
# 70                           NaN           2006
# 77             HKW Bad Salzungen           1994
# 83                             -           2013
# 96                           NaN           2013
# 110                            D           1968
# 111                            F           1971
# 112                            H           1974
# 113                            G           1974
# 114                            K           2002
# 115                            B           1963
# 116                            A           1963
# 117                            C           1965
# ...                          ...            ...
# 2018                   GT Ummeln           1975
# 2019                         KKG           1982
# 2020                           3           1970
# 2021                        4 GT           1974
# 2022                        4 DT           1975
# 2023                           1           1975
# 2024                           2           1975
# 2025                     Block 3           1966
# 2026                     Block 4           1970
# 2027                           F           1993
# 2028                         NaN           1996
# 2029              Lichterfelde 2           1973
# 2030                     Block 8           1982
# 2031                     Block 7           1978
# 2033                           C           1969
# 2034             Gaskesselanlage           1969
# 2035                        GT F           1989
# 2036                        GT G           1989
# 2037                        GT H           1989
# 2038                    Block 14           1972
# 2039                     Block 5           1968
# 2040                           D           2014
# 2041                     Block 3           1966
# 2042                     Block 2           1973
# 2046                     Herne 3           1966
# 2047                     Block A           1982
# 2048                     Block B           1985
# 2049                      West 2           1971
# 2050                      West 1           1971
# 2051                           B           1984
#
#                                      Status Energieträger   KWK Nettoleistung
# 6           Vorläufig Stillgelegt (mit StA)        Erdgas  Nein          37,5
# 7           Vorläufig Stillgelegt (mit StA)        Erdgas  Nein          37,5
# 8           Vorläufig Stillgelegt (mit StA)        Erdgas  Nein          37,5
# 9           Vorläufig Stillgelegt (mit StA)        Erdgas  Nein          37,5
# 15                               in Betrieb        Erdgas    Ja          11,0
# 22                               in Betrieb        Erdgas    Ja          65,0
# 23                               in Betrieb        Erdgas  Nein          50,0
# 24                               in Betrieb        Erdgas  Nein          57,0
# 25                               in Betrieb        Erdgas  Nein          81,0
# 26                               in Betrieb    Steinkohle    Ja         336,0
# 27                              Netzreserve    Steinkohle    Ja         433,0
# 36                               in Betrieb        Erdgas    Ja          15,1
# 38                               in Betrieb        Erdgas    Ja          28,0
# 43                               in Betrieb    Steinkohle    ja          19,0
# 50                               in Betrieb        Erdgas    Ja          47,0
# 54          Vorläufig Stillgelegt (mit StA)        Erdgas    Ja          29,0
# 55                               in Betrieb        Erdgas    Ja          30,7
# 56                              Netzreserve        Erdgas    Ja          20,4
# 70                               in Betrieb        Erdgas    Ja          10,7
# 77                               in Betrieb        Erdgas    Ja           9,7
# 83                               in Betrieb        Erdgas    Ja          17,8
# 96                               in Betrieb        Erdgas    Ja          78,0
# 110                              in Betrieb    Braunkohle  Nein         297,0
# 111                              in Betrieb    Braunkohle  Nein         299,0
# 112                              in Betrieb    Braunkohle  Nein         648,0
# 113                              in Betrieb    Braunkohle    Ja         628,0
# 114                              in Betrieb    Braunkohle  Nein         944,0
# 115        Vorläufig Stillgelegt (ohne StA)    Braunkohle  Nein         125,0
# 116        Vorläufig Stillgelegt (ohne StA)    Braunkohle  Nein         125,0
# 117                              in Betrieb    Braunkohle  Nein         295,0
# ...                                     ...           ...   ...           ...
# 2018   Endgültig Stillgelegt 2015 (mit StA)        Erdgas  Nein          55,0
# 2019   Endgültig Stillgelegt 2015 (mit StA)   Kernenergie  Nein       1.275,0
# 2020   Endgültig Stillgelegt 2015 (mit StA)    Steinkohle  Nein         303,0
# 2021   Endgültig Stillgelegt 2015 (mit StA)        Erdgas  Nein          65,0
# 2022   Endgültig Stillgelegt 2015 (mit StA)        Erdgas  Nein         335,0
# 2023   Endgültig Stillgelegt 2015 (mit StA)        Erdgas    Ja          80,0
# 2024   Endgültig Stillgelegt 2015 (mit StA)        Erdgas  Nein          80,0
# 2025   Endgültig Stillgelegt 2015 (mit StA)    Steinkohle    Ja         202,5
# 2026   Endgültig Stillgelegt 2015 (mit StA)    Steinkohle    Ja         202,5
# 2027   Endgültig Stillgelegt 2015 (mit StA)    Braunkohle    Ja          45,0
# 2028  Endgültig Stillgelegt 2015 (ohne StA)        Erdgas    Ja           9,0
# 2029   Endgültig Stillgelegt 2016 (mit StA)        Erdgas    Ja         144,0
# 2030   Endgültig Stillgelegt 2016 (mit StA)    Steinkohle    ja          35,0
# 2031   Endgültig Stillgelegt 2016 (mit StA)    Steinkohle    ja          23,0
# 2033   Endgültig Stillgelegt 2016 (mit StA)    Steinkohle  Nein         284,0
# 2034   Endgültig Stillgelegt 2016 (mit StA)        Erdgas    Ja          11,3
# 2035   Endgültig Stillgelegt 2016 (mit StA)        Erdgas  Nein          37,5
# 2036   Endgültig Stillgelegt 2016 (mit StA)        Erdgas  Nein          37,5
# 2037   Endgültig Stillgelegt 2016 (mit StA)        Erdgas  Nein          37,5
# 2038   Endgültig Stillgelegt 2016 (mit StA)        Erdgas    Ja         155,0
# 2039   Endgültig Stillgelegt 2016 (mit StA)    Steinkohle    Ja         127,0
# 2040  Endgültig Stillgelegt 2016 (ohne StA)    Steinkohle  Nein         765,0
# 2041   Endgültig Stillgelegt 2017 (mit StA)    Steinkohle    Ja          60,4
# 2042   Endgültig Stillgelegt 2017 (mit StA)        Erdgas    Ja          56,0
# 2046   Endgültig Stillgelegt 2017 (mit StA)    Steinkohle    Ja         280,0
# 2047   Endgültig Stillgelegt 2017 (mit StA)    Steinkohle  Nein         695,0
# 2048   Endgültig Stillgelegt 2017 (mit StA)    Steinkohle  Nein         695,0
# 2049   Endgültig Stillgelegt 2017 (mit StA)    Steinkohle  Nein         318,0
# 2050   Endgültig Stillgelegt 2017 (mit StA)    Steinkohle  Nein         322,0
# 2051  Endgültig Stillgelegt 2017 (ohne StA)   Kernenergie  Nein       1.284,0
#
# [511 rows x 13 columns]

# %%
#gas = pl3.loc[pl1.Energieträger == "Steinkohle"]

# %%
gases = pl3.loc[:]

# %%
atest = gases.groupby(["PLZ"]).count()

# %%
plz = "24939"
gases.loc[gases.PLZ == plz]
# Out:
#       BlockID                Unternehmen    Kraftwerksname    PLZ        Ort  \
# 433   BNA1819  Stadtwerke Flensburg GmbH  Heizkraftwerk FL  24939  Flensburg
# 434   BNA0270  Stadtwerke Flensburg GmbH  Heizkraftwerk FL  24939  Flensburg
# 435   BNA0271  Stadtwerke Flensburg GmbH  Heizkraftwerk FL  24939  Flensburg
# 436   BNA0272  Stadtwerke Flensburg GmbH  Heizkraftwerk FL  24939  Flensburg
# 2030  BNA0273  Stadtwerke Flensburg GmbH  Heizkraftwerk FL  24939  Flensburg
# 2031  BNA0274  Stadtwerke Flensburg GmbH  Heizkraftwerk FL  24939  Flensburg
#
#      Straße und Hausnummer (Standort Kraftwerk)          Bundesland Blockname  \
# 433                             Batteriestr. 48  Schleswig-Holstein  Block 12
# 434                             Batteriestr. 48  Schleswig-Holstein  Block 11
# 435                             Batteriestr. 48  Schleswig-Holstein  Block 10
# 436                             Batteriestr. 48  Schleswig-Holstein   Block 9
# 2030                            Batteriestr. 48  Schleswig-Holstein   Block 8
# 2031                            Batteriestr. 48  Schleswig-Holstein   Block 7
#
#      Inbetriebnahme                                Status Energieträger KWK  \
# 433            2016                            in Betrieb        Erdgas  Ja
# 434            1992                            in Betrieb    Steinkohle  ja
# 435            1988                            in Betrieb    Steinkohle  ja
# 436            1985                            in Betrieb    Steinkohle  ja
# 2030           1982  Endgültig Stillgelegt 2016 (mit StA)    Steinkohle  ja
# 2031           1978  Endgültig Stillgelegt 2016 (mit StA)    Steinkohle  ja
#
#      Nettoleistung
# 433           75,0
# 434           27,0
# 435           29,0
# 436           33,0
# 2030          35,0
# 2031          23,0

# %%
pl2 = pl1.rename(columns={ pl1.columns[0]: "BlockID", pl1.columns[3]: "PLZ", pl1.columns[4]: "Ort", pl1.columns[8]: "Inbetriebnahme", pl1.columns[9]: "Status", pl1.columns[15]: "KWK", pl1.columns[16]: "Nettoleistung"})
#pl3 = pl2.rename(columns={ pl1.columns[1]: "BlockID" })

# %%
pl2['Nettoleistung'] = pl2['Nettoleistung'].str.replace('.','')
pl2['Nettoleistung'] = pl2['Nettoleistung'].str.replace(',','.')
#pl2['Nettoleistung'] = pl2['Nettoleistung'].str.replace('\n','')
#pl2['Nettoleistung'] = pl2[pd.to_numeric(pl2["Nettoleistung"])]
#pl2['Nettoleistung'] = pl2['Nettoleistung'].str.replace(';','.')

# %%
#pl2[] = pl2[pd.to_numeric(pl2["Nettoleistung"])]
pl2['Nettoleistung'] = pl2['Nettoleistung'].apply(pd.to_numeric)

# %%
# pl2

# %%
cols = [10, 11,12,14,17,18,19]
pl3 = pl2.drop(pl2.columns[cols],axis=1)

# %%
# pl3

# %%
# Status: endgültig stillgelegt, vorläufig stillgelegt, in Betrieb, Sicherheitsbereitschaft, Sonderfall, 
# Stillegung: [Jahreszahl]
# StA: ja/ nein

# %%
newdf = pd.DataFrame()

# %%
def generate_decom_tuple(state):
    if state == "In Betrieb":
        return("in Betrieb", "0")
    elif "Endgültig Stillgelegt" in state:
        a = "stillgelegt"
        b = str(int(state[22:26]))
        return (a, b)
    elif "Vorläufig Stillgelegt" in state:
        a = "vorläufig stillgelegt"
        return (a, "0")
    else:
        return(state, "0")

# %%
def fix_company(company):
    cmp = company
    company_prefix, _ = company.split(" " , 1)
    # company_dict = {}
    company_dict = {"RWE": "RWE AG", "Vattenfall": "Vattenfall GmbH", "Uniper": "Uniper SE", "EnBW": "EnBW AG", "Steag": "Steag GmbH", "Nordzucker": "Nordzucker AG"}
    try:
        cmp = company_dict[company_prefix]
    except KeyError:
        return company
    return cmp

# %%
for index, row in pl3.iterrows():
    #if row['Status'] == "Endgültig Stillgelegt 2016 (mit StA)":
    # print(row)
    if row['KWK'] == "nein":
        row['KWK'] = "Nein" # workaround for BoA plants
    status, stilllegung = generate_decom_tuple(row['Status'])
    cmp = fix_company(row['Unternehmen'])
    row['Unternehmen'] = cmp
    row['Status'] = status
    row['Stilllegung'] = stilllegung
    newdf = newdf.append(row)

# %%
# newdf['Stilllegung'] = newdf['Stilllegung'].astype(int)
#newdf['Stilllegung'] = newdf['Stilllegung'].apply(lambda x: int(x) if x == x else None)

# %%
newdf['Stilllegung'] = newdf['Stilllegung'].replace("0", np.nan)

# %%
pl3 = newdf

# %%
atest = newdf.groupby(["Unternehmen"]).count()
atest.sort_values("BlockID", inplace=True, ascending=False)

# %%
print(atest)
# Out:
#                                                     BlockID  Blockname  \
# Unternehmen
# ..                    ...       ...
# 380      06-02-B10117A007   BNA0402
# 381     03-10-10257673950   BNA0602
# 382     03-10-10257673950   BNA0603
# 383     03-10-10257673950   BNA0604
# 384     03-10-10257673950   BNA0605
# 385     03-10-10257673950   BNA0606
# 386     03-10-10257673950   BNA0607
# 387   06-09-100-0020-0001  BNA0842a
# 388   06-09-100-0020-0001  BNA0842b
# 389     03-03-03030273580  BNA0918a
# 390     03-03-03030273580  BNA0918b
# 391     03-03-03267770260   BNA1437
# 392     06-05-300-0838652  BNA0117b
# 393        06-26200010633  BNA0059a
# 394        06-26200010633  BNA0059b
# 395   06-09-661-0020-0001  BNA1337a
# 396   06-09-661-0020-0001  BNA1337e
# 397     14-20-60319980000   BNA1541
# 398     14-70-51322590000   BNA1556
# 399     03-09-09261732970   BNA1671
# 400  06-04-11/2001178/8/2   BNA1334
# 401  06-04-11/2001178/8/2   BNA1820
# 402  06-04-11/2001178/8/2   BNA0145
# 403  06-04-11/2001178/8/2   BNA0145
# 404     01-50-01000004838   BNA1819
# 405     01-50-01000004838   BNA0270
# 406     01-50-01000004838   BNA0271
# 407     01-50-01000004838   BNA0272
# 408     01-50-01000004838   BNA0273
# 409     01-50-01000004838   BNA0274
#
# [410 rows x 2 columns]

# %%
pl4 = bm.merge(pl3, how="outer", on="BlockID")

# %%
pl5 = pl4[pd.notnull(pl4['BlockID'])]
#pl5 = pl4
pl6 = pl5[pd.notnull(pl5['Nettoleistung'])]

# %%
# pl6

# %%
blocks = pl6.copy()
stammdaten = pl6.copy()

# %%
blocks.sort_values("Nettoleistung", inplace=True, ascending=False)
# blocks

# %%
plants = blocks.loc[:]
plants = plants.dropna(subset=["KraftwerkID"])

# %%
plants_d = plants.loc[plants.duplicated("KraftwerkID", keep=False)]
# plants_d

# %%
plants_c = plants_d.groupby(["KraftwerkID"]).sum()
plants_count = plants_d.groupby(["KraftwerkID"]).count()

# %%
plants_f = plants_c.reset_index()

# %%
plants_count = plants_count.loc[:, ["BlockID"]]

# %%
plants_count = plants_count.reset_index()
# plants_count

# %%
plants_f = plants_f.merge(plants_count, on="KraftwerkID", how="inner")
# plants_f

# %%
plants_a = plants.drop_duplicates(subset="KraftwerkID")

# %%
plants_b = plants_d.loc[:]

# %%
plants_f = plants_f.rename(columns={ "Nettoleistung": "Gesamtleistung", "BlockID": "Blockzahl"})

# %%
plants_f = plants_f.merge(plants_a, on="KraftwerkID", how="left")
# plants_f

# %%
blocks.drop_duplicates(subset="BlockID", inplace=True)

# %%
#cols = [4,5,6,8]
#blocks.drop(blocks.columns[cols],axis=1, inplace=True)
#test_blocks = blocks.drop(blocks.columns[cols],axis=1)

# %%
blocks.drop(['Ort', 'PLZ', 'Straße und Hausnummer (Standort Kraftwerk)', 'Blockname'], axis=1, inplace=True)

# %%
plants_f.sort_values("Gesamtleistung", ascending=False, inplace=True)

# %%
drop_list = ['Blockname', 'KWK', 'Nettoleistung', 'Stilllegung', 'Straße und Hausnummer (Standort Kraftwerk)', 'PLZ', 'Ort', 'Nettoleistung']
plants_g = plants_f.drop(drop_list, axis=1)

# %%
plants_h = plants_g.rename(columns={"KraftwerkID": "plantid", "Gesamtleistung": "totalpower", "Blockzahl": "blockcount", "BlockID": "blockid", "Bundesland": "federalstate", "Energieträger": "energysource", "Inbetriebnahme": "latestexpanded", "Kraftwerksname": "plantname", "Status": "state", "Unternehmen": "company"})

# %%
plants_h['latestexpanded'] = plants_h['latestexpanded'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-9ef7edc08c57> in <module>()
# ----> 1 plants_h['latestexpanded'] = plants_h['latestexpanded'].astype(int)
#
# /usr/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# /usr/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4004                                      **kwargs)
#    4005         return self._constructor(new_data).__finalize__(self)
#    4006
#
# /usr/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, **kwargs)
#    3460
#    3461     def astype(self, dtype, **kwargs):
# -> 3462         return self.apply('astype', dtype=dtype, **kwargs)
#    3463
#    3464     def convert(self, **kwargs):
#
# /usr/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3327
#    3328             kwargs['mgr'] = self
# -> 3329             applied = getattr(b, f)(**kwargs)
#    3330             result_blocks = _extend_blocks(applied, result_blocks)
#    3331
#
# /usr/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     542     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     543         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 544                             **kwargs)
#     545
#     546     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# /usr/lib/python3.6/site-packages/pandas/core/internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, **kwargs)
#     623
#     624                 # _astype_nansafe works fine with 1-d only
# --> 625                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     626                 values = values.reshape(self.shape)
#     627
#
# /usr/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy)
#     690     elif arr.dtype == np.object_ and np.issubdtype(dtype.type, np.integer):
#     691         # work around NumPy brokenness, #1987
# --> 692         return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     693
#     694     if dtype.name in ("datetime64", "timedelta64"):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# pandas/_libs/src/util.pxd in util.set_value_at_unsafe()
#
# ValueError: invalid literal for int() with base 10: '2005 / 2012'

# %%
plants_i = plants_h[["plantid", "plantname", "federalstate", "energysource", "latestexpanded", "totalpower", "state", "blockcount", "blockid", "company"]]

# %%
plants_h.shape

# %%
plants_i.shape

# %%
plants_h.dtypes

# %%
# plants_i

# %%
# test_blocks

# %%
#blocks.loc[blocks.Energieträger == 'Erdgas',]

# %%
plants_final = plants_i.loc[:]

# %%
# plants_final

# %%
# stammdaten

# %%
# cols = [0,2,3,9,10,11,12]
drop_list = ['KraftwerkID', 'Blockname', 'Energieträger', 'Inbetriebnahme', 'KWK', 'Kraftwerksname', 'Nettoleistung', 'Status', 'Stilllegung', 'Unternehmen']
stammdaten.drop(drop_list, axis=1, inplace=True)

# %%
#stammdaten.to_csv("stammdaten.csv", index=False)

# %%
#plants_final.to_csv("plants.csv", index=False)

# %%
#blocks.to_csv("blocks_3.csv", index=False)

# %%
#stammdaten.to_csv("stammdaten_nh.csv", index=False, header=False)
#blocks.to_csv("blocks_nh.csv", index=False, header=False)
#plants_final.to_csv("plants_nh.csv", index=False, header=False)
